# %% [markdown]
# # Olist E-Commerce – Exploratory Analysis
#
# This notebook performs lightweight validation and exploration on the final
# BigQuery data marts used for reporting.

# %%
SELECT
  COUNT(*) AS row_count,
  COUNT(DISTINCT customer_id) AS customers
FROM `YOUR_PROJECT_ID.olist_mart.rfm`;
# Out:
#   File "/tmp/ipython-input-1710936921.py", line 2
#     COUNT(*) AS rows,
#     ^
# IndentationError: unexpected indent

# %%
SELECT
  MIN(purchase_date) AS start_date,
  MAX(purchase_date) AS end_date,
  SUM(revenue_gross) AS total_revenue
FROM `YOUR_PROJECT_ID.olist_mart.sales_daily`;

# %% [markdown]
# ## Conclusion
#
# This notebook is used for validation and exploration only.
# All transformations and business logic are implemented in SQL.

# %% [markdown]
# ## Summary
#
# This notebook performs basic validation and exploration of the final data marts.
# All business logic and transformations are implemented in SQL within BigQuery.
